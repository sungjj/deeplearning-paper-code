# %% [markdown]
# > ### EEE4423: Deep Learning Lab
#
# # LAB #7: High-level Vision - Single Shot Object Detection (YOLO)

# %% [markdown]
# <h4><div style="text-align: right"> Due date: APRIL 20, 2022.  </div> <br>
# <div style="text-align: right"> Please upload your file @ LearnUs by 2 PM in the form of [ID_Name_Lab07.ipynb]. </div></h4>

# %% [markdown]
# ### *Instructions:*
# - Write a program implementing a particular algorithm to solve a given problem.
# - <span style="color:red">**Report and discuss your results. Analyze the algorithm, theoretically and empirically.**</span>
# - Each team must write their own answers and codes (<span style="color:red">**if not you will get a F grade**</span>).

# %% [markdown]
# <h2><span style="color:blue">[2019142079] [성재진]</span> </h2>

# %%
import datetime
print("This code is written at " + str(datetime.datetime.now()))

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.transforms as transforms
import torch.utils.data as data
from torch.autograd import Variable

import torchvision.datasets as dsets

import numpy as np
import cv2

import os
import struct
import copy
import random

import time
import datetime

import math

from PIL import Image
import torchvision.transforms as transforms
from torchvision.transforms import Compose, ToTensor, Resize
from torch.utils import data
from torch.utils.data import DataLoader

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 1. What is the Object Detection?
#
# >
# > <img src="https://drive.google.com/uc?export=view&id=1pOo5As8Qo8bQOQjOkkpRwjVKcKNB4gSE" alt="no_image" style="width: 800px;"/>
# >
# > - The difference between $\bf{classification}$ (left) and $\bf{detection}$ (right) is simple
# >
# > - In image classification, the entire image is classified with a single label
# >
# > - In object detection, the network localizes (potentially multiple) objects within the image
# >
# > - Therefore, given the image, the obejct detection networks ouput a list of bounding box, class label, and **probability/confidence score**
# >
#
# ### 2. About YOLO (Main idea)
#
# >
# > <img src="https://drive.google.com/uc?export=view&id=1K7tvcGXdRHBc_t5p-m3uyRrCBFbJ9ze5" alt="no_image" style="width: 800px;"/>
# >
# > - YOLO is an algorithm for object detection
# >
# > - They reframe object detection as a $\bf{single\ regression\ problem}$, straight from image pixels to bounding box coordinates and class probabilities
# >
# > - Using YOLO, you only look once (YOLO) at an image to predict what objects are present and where they are
# >
# > - The advantage of YOLO is the speed, which is extremely fast, since the authors reframe detection as a regression problem not using a complex pipeline
# >
# > - What are differences between YOLO and previous detectors?? Refer to https://towardsdatascience.com/r-cnn-fast-r-cnn-faster-r-cnn-yolo-object-detection-algorithms-36d53571365e

# %% [markdown]
# ### 3. Building a YOLO with PyTorch
#
# > ### YOLO model:
# > - 22Convolutional Layers
# >
# >     - Note that, first and 20th conv layers have stride 2 for halving output size
# >
# > - 4 Max Pooling Layers
# >
# > - 2 Fully Connected Layers
# >
# > - Leaky ReLu Activation for all layers except for the last layer
#
# ### 4. Implementing YOLO
# >
# > - The input image is divided into an S $\times$ S grid of cells
# >
# > - Each grid cell predicts B (=2) bounding boxes as well as C (=20) class probabilities
# >
# > - Each bounding box consists of 5 predictions: x, y, w, h, and confidence
# >
# > - The (x,y) coordinates represent the center of the box relative to the bounds of the grid cell
# >
# > - The width and height are predicted relative to the whole image
# >
# > - If no object exists in that cell, the confidence score is zero.
# >
# > - If the cell contains objects, the confidence score is equal to the intersection over union (IOU) between the predicted box and the ground truth (**This is important for building the loss function**)
# >
# > - Thus, the output vector is a S $\times$ S $\times$ (B $\times$ 5 + C) (= 7 $\times$ 7 $\times$ 30)
# >
# > <img src="https://drive.google.com/uc?export=view&id=1LdKtTyYjGKKWmu-4nTYBEMI7n4Sk0aeB" alt="no_image" style="width: 600px;"/>
# >
# > - You must study *generate_target* function in detail, it contains the process of generating output vectors
# >
# > Step 1: Load the dataset
# >
# > Step 2: Build the YOLO network ($\bf{4 points}$)
# >>
# >>  <img src="https://drive.google.com/uc?export=view&id=1c4yOWTZacei0_pFoI47wfxVEhM5Tms8X" alt="no_image" style="width: 800px;"/>
# >>
# >> - Following the YOLO model, you build yolo network
# >> - **Note that our model is different from network of original paper. Please follow above figure.**
# >> - You must fill out the blank in **self.pre_train_net** and **self.post_net** blocks
# >> - All layers use the following Leaky ReLU (0.01 slope for negative part - Note that it is different from the paper)
# >>
# >>
# >> #### **self.pre_train_net**
# >>
# >>
# >>
# >>| Name       | Filters              | Output Dimension | Padding |
# >>|------------|----------------------|------------------| ------- |
# >>| Conv 1     | 7 x 7 x 64, stride=2 | 224 x 224 x 64   | 3       |
# >>| LeakyReLU  | negative_slop=0.01   | 224 x 224 x 64   |         |
# >>| Max Pool 1 | 2 x 2, stride=2      | 112 x 112 x 64   |         |
# >>|
# >>| Conv 2     | 3 x 3 x 192          | 112 x 112 x 192  | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 112 x 112 x 192  |         |
# >>| Max Pool 2 | 2 x 2, stride=2      | 56 x 56 x 192    |         |
# >>|
# >>| Conv 3     | 1 x 1 x 128          | 56 x 56 x 128    | 0       |
# >>| LeakyReLU  | negative_slop=0.01   | 56 x 56 x 128    |         |
# >>| Conv 4     | 3 x 3 x 256          | 56 x 56 x 256    | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 56 x 56 x 256    |         |
# >>| Conv 5     | 1 x 1 x 256          | 56 x 56 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.01   | 56 x 56 x 256    |         |
# >>| Conv 6     | 3 x 3 x 512          | 56 x 56 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 56 x 56 x 512    |         |
# >>| Max Pool 3 | 2 x 2, stride=2      | 28 x 28 x 512    |         |
# >>|
# >>| Conv 7     | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 256    |         |
# >>| Conv 8     | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 512    |         |
# >>| Conv 9     | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 256    |         |
# >>| Conv 10    | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 512    |         |
# >>| Conv 11    | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 256    |         |
# >>| Conv 12    | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 512    |         |
# >>| Conv 13    | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 256    |         |
# >>| Conv 14    | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 512    |         |
# >>| Conv 15    | 1 x 1 x 512          | 28 x 28 x 512    | 0       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 512    |         |
# >>| Conv 16    | 3 x 3 x 1024         | 28 x 28 x 1024   | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 28 x 28 x 1024   |         |
# >>| Max Pool 4 | 2 x 2, stride=2      | 14 x 14 x 1024   |         |
# >>|
# >>| Conv 17    | 1 x 1 x 512          | 14 x 14 x 512    | 0       |
# >>| LeakyReLU  | negative_slop=0.01   | 14 x 14 x 512    |         |
# >>| Conv 18    | 3 x 3 x 1024         | 14 x 14 x 1024   | 1       |
# >>| LeakyReLU  | negative_slop=0.01   | 14 x 14 x 1024   |         |
# >>
# >> #### **self.post_net**
# >>
# >>| Name      | Filters                | Output Dimension | Padding |
# >>|-----------|------------------------|------------------| ------- |
# >>| Conv 19   | 3 x 3 x 1024           | 14 x 14 x 1024   | 1       |
# >>| LeakyReLU | negative_slop=0.01     | 14 x 14 x 1024   |         |
# >>| Conv 20   | 3 x 3 x 1024, stride=2 | 7 x 7 x 1024     | 1       |
# >>| LeakyReLU | negative_slop=0.01     | 7 x 7 x 1024     |         |
# >>| Conv 21   | 3 x 3 x 1024           | 7 x 7 x 1024     | 1       |
# >>| LeakyReLU | negative_slop=0.01     | 7 x 7 x 1024     |         |
# >>| Conv 22   | 3 x 3 x 1024           | 7 x 7 x 1024     | 1       |
# >>| LeakyReLU | negative_slop=0.01     | 7 x 7 x 1024     |         |
# >>
# > Step 3: Loss function ($\bf{6 points}$)
# >
# >> - Fill out the code considering the loss function in YOLO
# >> - The loss function is composed like below
# >> <img src="https://drive.google.com/uc?export=view&id=1QcAP__J50M379GAul7SlhAzzU551tuDj" alt="no_image" style="width: 600px;"/>
# >>
# >> - $\mathbb{1}_{obj}$ is defined as follows:
# >>    - 1, if an object is present in grid cell $i$ and the $j$th bounding box predictor
# >>    - 0, otherwise
# >>
# >> - YOLO predicts multiple bounding boxes per grid cell (in our case, 2 bounding boxes are predicted)
# >> - In train stage, YOLO requires one bounding box predictor to be responsible for each object
# >> - The code assigns one predictor to be "responsible" for predicting an object where the predictor has the highest IOU with the ground truth
# >> - The loss function is divided into the three sub-sections
# >>    1. Classification ( $\bf{6}$ classes ) ($\bf{2 points}$)
# >>       <img src="https://drive.google.com/uc?export=view&id=13mnxg_GNtbWnYLpe1P6zopf693zTYe22" alt="no_image" style="width: 300px;"/>
# >>
# >>       - Similar to sum-squared error for classification except for $\mathbb{1}_{obj}$ term
# >>
# >>       - Note that, we do not penalize classification error when no object is present on the cell (by $\mathbb{1}_{obj}$ term)
# >>
# >>    2. No object appears in cell ($\bf{2 points}$)
# >>       <img src="https://drive.google.com/uc?export=view&id=1R74HzbRLoX2K5zun8XSLAnRQlKq25XFV" alt="no_image" style="width: 300px;"/>
# >>
# >>       - Compute the loss associated with the confidence score for each bounding box predictor
# >>
# >>       - $\mathbb{1}_{noobj}$ is equal to one when there is no object in the cell, and 0 other wise
# >>    3. Bounding box coordinates (x,y,h,w) regression (4 scalars), and Object confidence ($\bf{2 points}$)
# >>       <img src="https://drive.google.com/uc?export=view&id=1lXs5lHUiXGxgMRNCiViY6SyRDL52gQsy" alt="no_image" style="width: 600px;"/>
# >>
# >>       - Compute the loss realted to the predicted bounding box position $(x,y)$ and width/height $(w,h)$
# >>
# >>       - Note that width/height are adapted square root before computing the loss
# >>
# >>       - In order to solve the problem that small deviations in large boxes matter less than in small boxes
# >>
# >>       - Compute the loss associated with the confidence score for the cell which is responsible for the object
# >>
# >> - Following the paper, $\lambda_{coord} = 5$ and $\lambda_{noobj} = 0.5$
# >>
# > Step 4: Train Model ($\bf{2 points}$)
# >>
# >> - Based on the above code, you build train code on your own
# >> - The necessary things are provided (e.g., *optimizer* and *num_epoch*)
# >> - Note that, we offer the pre-trained model since it requires large training time.
# >> - If you construct your code correctly, the performance of mAP will be over 0.69 mAP in 10 epochs (about 15 minitues.)
# >>
# > Step 5: Inference
# >>
# >> - We offer the test code in below
# >> - You can check the qualitative results using the visualization code
# >> - The quantitative results will be evaluated by using the mAP code
# >> - If the performance of mAP is significantly decreased from the pre-trained model (0.685 mAP), your code will be wrong
# >>
# >> Step 5-1: Inference (Visualization)
# >>
# >> Step 5-2: Inference (mAP)

# %% [markdown]
# ### Step 1. Load the dataset

# %%
# os.environ["CUDA_VISIBLE_DEVICES"] = "0"

class YoloDataset(data.Dataset):
    def __init__(self, root, list_file, train, transform=None):
        self.image_size = 448
        self.root = root
        self.train = train
        self.transform = transform
        self.fnames = []
        self.boxes = []
        self.labels = []
        self.color_jitter = Compose([transforms.ColorJitter(brightness=0.1,contrast=0.1, saturation=0.1, hue=0.1),
                                                 transforms.ToTensor()])
        self.plain = Compose([transforms.ToTensor()])
        self.resize = Compose([transforms.ToPILImage(),
                              transforms.Resize((self.image_size, self.image_size)),
                              transforms.ToTensor()])
        
        with open(list_file) as f:
            lines = f.readlines()
            
        for line in lines:
            splited = line.strip().split()
            self.fnames.append(splited[0])
            num_boxes = (len(splited) - 1) // 5
            box = []
            label = []
            for i in range(num_boxes):
                x_min = float(splited[1+5*i])
                y_min = float(splited[2+5*i])
                x_max = float(splited[3+5*i])
                y_max = float(splited[4+5*i])
                c = splited[5+5*i]
                box.append([x_min, y_min, x_max, y_max])
                label.append(int(c)+1)
            self.boxes.append(torch.Tensor(box))
            self.labels.append(torch.LongTensor(label))
        self.num_samples = len(self.boxes)
        
    def img_pre_process(self, img, boxes, labels):
        
        if random.random() < 0.5:
            im_lr = np.fliplr(img).copy()
            height, width, c = img.shape
            x_min = width - boxes[:, 2]
            x_max = width - boxes[:, 0]
            boxes[:,0] = x_min
            boxes[:,2] = x_max
            img = im_lr
        
        ## Converting the image and box information scaling
        if random.random() < 0.5:
            scale = random.uniform(0.8, 1.2)
            height, width, c = img.shape
            img = cv2.resize(img, (int(width * scale), height))
            boxes = boxes * torch.FloatTensor([[scale, 1, scale, 1]]).expand_as(boxes)
            
        ## Image translation
        if random.random() < 0.5:
            center = (boxes[:,2:] + boxes[:,:2]) / 2
            height, width, c = img.shape
            shifted_img = np.zeros((height, width, c), dtype=img.dtype)
            
            w_range = int(random.uniform(-width*0.2, width*0.2))
            h_range = int(random.uniform(-height*0.2, height*0.2))
            
            if w_range<0 and h_range<0:
                shifted_img[:height+h_range,:width+w_range,:] = img[-h_range:,-w_range:,:]
                
            elif w_range<0 and h_range>=0:
                shifted_img[h_range:,:width+w_range,:] = img[:height-h_range,-w_range:,:]
            
            elif w_range>=0 and h_range>=0:
                shifted_img[h_range:,w_range:,:] = img[:height-h_range,:width-w_range,:]
                
            elif w_range>=0 and h_range<0:
                shifted_img[:height+h_range,w_range:,:] = img[-h_range:,:width-w_range,:]
                
            wh_range = torch.FloatTensor([[w_range, h_range]]).expand_as(center)
            center = center + wh_range
            
            mask1 = (center[:,0] > 0) & (center[:,0] < width)
            mask2 = (center[:,1] > 0) & (center[:,1] < height)
            mask = (mask1 & mask2).view(-1,1).bool()
            
            boxes_in = boxes[mask.expand_as(boxes)].view(-1,4)
            
            if len(boxes_in) != 0:
                box_shift = torch.FloatTensor([[w_range, h_range, w_range, h_range]]).expand_as(boxes_in)
                boxes_in = boxes_in + box_shift
                
                labels_in = labels[mask.view(-1)]
                labels = labels_in
                img = shifted_img
                boxes = boxes_in
        
        ## Image cropping
        if random.random() < 0.5:
            center = (boxes[:,2:] + boxes[:,:2]) / 2
            height, width, c = img.shape
            h = int(random.uniform(0.6*height,height))
            w = int(random.uniform(0.6*width,width))
            x = int(random.uniform(0,width-w))
            y = int(random.uniform(0,height-h))
            
            center = center - torch.FloatTensor([[x, y]]).expand_as(center)
            mask1 = (center[:,0]>0) & (center[:,0]<w)
            mask2 = (center[:,1]>0) & (center[:,1]<h)
            mask = (mask1 & mask2).view(-1, 1).bool()
            
            boxes_in = boxes[mask.expand_as(boxes)].view(-1,4)
            
            if (len(boxes_in)!=0):
                box_shift = torch.FloatTensor([x,y,x,y]).expand_as(boxes_in)

                boxes_in = boxes_in - box_shift
                boxes_in[:,0]=boxes_in[:,0].clamp_(min=0,max=w)
                boxes_in[:,2]=boxes_in[:,2].clamp_(min=0,max=w)
                boxes_in[:,1]=boxes_in[:,1].clamp_(min=0,max=h)
                boxes_in[:,3]=boxes_in[:,3].clamp_(min=0,max=h)

                labels = labels[mask.view(-1)]
                img_cropped = img[y:y+h, x:x+w, :]
                boxes = boxes_in
                img = img_cropped
        
        return img, boxes, labels

    def generate_target(self, img, boxes, labels):
        grid_size = 7
        h,w,_ = img.shape
        boxes /= torch.Tensor([w,h,w,h]).expand_as(boxes) # Converting the box size 0 ~ 1
        target = torch.zeros((grid_size, grid_size, 30)) 
        cell_size = 1./grid_size 

        wh = boxes[:,2:] - boxes[:,:2]
        cxcy = (boxes[:,2:] + boxes[:,:2]) / 2
        
        for i in range(cxcy.size()[0]):
            cxcy_sample = cxcy[i] # center pixel 
            ij = (cxcy_sample/cell_size).ceil()-1 
            target[int(ij[1]),int(ij[0]),4] = 1
            target[int(ij[1]),int(ij[0]),9] = 1
            target[int(ij[1]),int(ij[0]),int(labels[i])+9] = 1
            
            xy = ij*cell_size 
            delta_xy = (cxcy_sample -xy)/cell_size # Converting delta_xy to the size 
                                                   # relative to the bounds of the grid cell
            target[int(ij[1]),int(ij[0]),2:4] = wh[i]
            target[int(ij[1]),int(ij[0]),:2] = delta_xy
            target[int(ij[1]),int(ij[0]),7:9] = wh[i]
            target[int(ij[1]),int(ij[0]),5:7] = delta_xy
            
        return target
    
    def RandomBrightness(self,bgr):
        if random.random() < 0.5:
            hsv = cv2.cvtColor(bgr,cv2.COLOR_BGR2HSV)
            h,s,v = cv2.split(hsv)
            adjust = random.choice([0.5,1.5])
            v = v*adjust
            v = np.clip(v, 0, 255).astype(hsv.dtype)
            hsv = cv2.merge((h,s,v))
            bgr = cv2.cvtColor(hsv,cv2.COLOR_HSV2BGR)
        return bgr
    def RandomSaturation(self,bgr):
        if random.random() < 0.5:
            hsv = cv2.cvtColor(bgr,cv2.COLOR_BGR2HSV)
            h,s,v = cv2.split(hsv)
            adjust = random.choice([0.5,1.5])
            s = s*adjust
            s = np.clip(s, 0, 255).astype(hsv.dtype)
            hsv = cv2.merge((h,s,v))
            bgr = cv2.cvtColor(hsv,cv2.COLOR_HSV2BGR)
        return bgr
    def RandomHue(self,bgr):
        if random.random() < 0.5:
            hsv = cv2.cvtColor(bgr,cv2.COLOR_BGR2HSV)
            h,s,v = cv2.split(hsv)
            adjust = random.choice([0.5,1.5])
            h = h*adjust
            h = np.clip(h, 0, 255).astype(hsv.dtype)
            hsv = cv2.merge((h,s,v))
            bgr = cv2.cvtColor(hsv,cv2.COLOR_HSV2BGR)
        return bgr

    def randomBlur(self,bgr):
        if random.random()<0.5:
            bgr = cv2.blur(bgr,(5,5))
        return bgr
        
    def __getitem__(self, idx):
        fname = self.fnames[idx]
        img = cv2.imread(os.path.join(self.root+fname))
        boxes = self.boxes[idx].clone()
        labels = self.labels[idx].clone()

        if self.train:
            img = self.randomBlur(img)
            img = self.RandomBrightness(img)
            img = self.RandomHue(img)
            img = self.RandomSaturation(img)
            img, boxes, labels = self.img_pre_process(img, boxes, labels)
            
        target = self.generate_target(img, boxes, labels) # 7x7x30
        
        # Image processing
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        img = self.plain(img)
        img = self.resize(img)
        img = 2 * img - 1
        
        return img, target
    
    def __len__(self):
        return self.num_samples

# %% [markdown]
# ### Step 2. Build the YOLO network (2 points)

# %% [markdown]
# > You should build model using nn.Sequential. Otherwise, problem arises when loading pretrained weights.

# %%
class YOLO(nn.Module):
    def __init__(self):
        super(YOLO, self).__init__()
        
        self.pre_train_net = nn.Sequential(
            ################
            #Conv1
            nn.Conv2d(in_channels=3, out_channels=64, kernel_size=7, stride=2, padding=3),
            nn.LeakyReLU(negative_slope=0.01, inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            #Conv2
            nn.Conv2d(in_channels=64, out_channels=192, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope=0.01, inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            #Conv3
            nn.Conv2d(in_channels=192, out_channels=128, kernel_size=1, stride=1, padding=0),
            nn.LeakyReLU(negative_slope=0.01, inplace=True),
            #Conv4
            nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope=0.01, inplace=True),
            #Conv5
            nn.Conv2d(in_channels=256, out_channels=256, kernel_size=1, stride=1, padding=0),
            nn.LeakyReLU(negative_slope=0.01, inplace=True),
            #Conv6
            nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope=0.01, inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            #Conv7
            nn.Conv2d(in_channels=512, out_channels=256, kernel_size=1, stride=1, padding=0),
            nn.LeakyReLU(negative_slope=0.01, inplace=True),
            #Conv8
            nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope=0.01, inplace=True),
            #Conv9
            nn.Conv2d(in_channels=512, out_channels=256, kernel_size=1, stride=1, padding=0),
            nn.LeakyReLU(negative_slope=0.01, inplace=True),
            #Conv10
            nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope=0.01, inplace=True),
            #Conv11
            nn.Conv2d(in_channels=512, out_channels=256, kernel_size=1, stride=1, padding=0),
            nn.LeakyReLU(negative_slope=0.01, inplace=True),
            #Conv12
            nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope=0.01, inplace=True),
            #Conv13
            nn.Conv2d(in_channels=512, out_channels=256, kernel_size=1, stride=1, padding=0),
            nn.LeakyReLU(negative_slope=0.01, inplace=True),
            #Conv14
            nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope=0.01, inplace=True),
            #Conv15
            nn.Conv2d(in_channels=512, out_channels=512, kernel_size=1, stride=1, padding=0),
            nn.LeakyReLU(negative_slope=0.01, inplace=True),
            #Conv16
            nn.Conv2d(in_channels=512, out_channels=1024, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope=0.01, inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            #Conv17
            nn.Conv2d(in_channels=1024, out_channels=512, kernel_size=1, stride=1, padding=0),
            nn.LeakyReLU(negative_slope=0.01, inplace=True),
            #Conv18
            nn.Conv2d(in_channels=512, out_channels=1024, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope=0.01, inplace=True)


            
            
            ################
        )
        
        self.post_net = nn.Sequential(
            ################
            #Conv19
            nn.Conv2d(in_channels=1024, out_channels=1024, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope=0.01, inplace=True),
            #Conv20
            nn.Conv2d(in_channels=1024, out_channels=1024, kernel_size=3, stride=2, padding=1),
            nn.LeakyReLU(negative_slope=0.01, inplace=True),
            #Conv21
            nn.Conv2d(in_channels=1024, out_channels=1024, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope=0.01, inplace=True),
            #Conv22
            nn.Conv2d(in_channels=1024, out_channels=1024, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(negative_slope=0.01, inplace=True)
            
            
            
            ################
        )
        
        self.FC1 = nn.Sequential(
            nn.Linear(50176, 4096),
            nn.LeakyReLU(),
            nn.Dropout()
        )
        
        self.FC2 = nn.Sequential(
            nn.Linear(4096, 1470)
        )
        
        self.pre_train_net.cuda()
        self.post_net.cuda()
        self.FC1.cuda()
        self.FC2.cuda()
        
        self._initialize_weights()

    def forward(self, x):
        output = self.pre_train_net(x)
        output = self.post_net(output)

        # Ready to going for FC layer
        output = output.view(output.size(0), -1)

        output = self.FC1(output)
        output = self.FC2(output)

        output = output.view(output.size(0), 7, 7, 30)
        # Converting the output shape to the (batch_size, 7, 7, 30)
        output = F.relu(output)

        return output
    
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
                if m.bias is not None:
                    m.bias.data.zero_()
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
            elif isinstance(m, nn.Linear):
                m.weight.data.normal_(0, 0.01)
                m.bias.data.zero_()

# %% [markdown]
# ### Step 3. Loss function (6 points)

# %%
class yoloLoss(nn.Module):
    def __init__(self,l_coord,l_noobj):
        super(yoloLoss,self).__init__()
        self.l_coord = l_coord
        self.l_noobj = l_noobj
    
    def compute_prob_error(self, pred, target): ## classification error
        contain = target[:,:,:,4] > 0 # [Batch_size, 7, 7, 1] #만약 cell에 object가 존재한다면 contain
        contain = contain.unsqueeze(3).expand_as(target) # [Batch_size, 7, 7, 30]
        
        ################30으로 view 하는 이유: x1, y1, w1, h1, confidence1, x2, y2, w2, h2, confidence2, c1, c2, c3, ... c20
        #으로 30까지 채워진다.
        target_contain=target[contain].contiguous().view(-1,30) #cell contains an object
        pred_contain=pred[contain].contiguous().view(-1,30) #cell contains an object
        prob_loss=F.mse_loss(pred_contain[:,10:], target_contain[:,10:],size_average=False)#class probability
        ################
        
        return prob_loss
    
    def not_contain_obj_error(self, pred, target): ## Error where no object appears in cell
        not_contain = target[:,:,:,4] == 0 # [Batch_size, 7, 7, 1]
        not_contain = not_contain.unsqueeze(3).expand_as(target) # [Batch_size, 7, 7, 30]
        
        ################
        target_not_contain=target[not_contain].contiguous().view(-1,30)#cell doesn't contain an object
        pred_not_contain=pred[not_contain].contiguous().view(-1,30)#cell doesn't contain an object
        
        pred_not_contain_mask=torch.cuda.ByteTensor(pred_not_contain.size()).zero_().bool()
        pred_not_contain_mask[:,[4,9]]=1    #cell's confidence score index's boolean is true which doesn't contain an object
        
        noobj_loss1=F.mse_loss(pred_not_contain[pred_not_contain_mask],target_not_contain[pred_not_contain_mask],size_average=False)#calculate loss which doesn't contain an object
        ################
        
        return noobj_loss1
    
    
    def contain_obj_error(self, pred, target): ##
        contain = target[:,:,:,4] > 0 # [Batch_size, 7, 7, 1]
        contain = contain.unsqueeze(3).expand_as(target) # [Batch_size, 7, 7, 30]
        
        contain_pred = pred[contain].contiguous().view(-1,30) # Only cell which contains the object are remained
        box_pred = contain_pred[:,:10].contiguous().view(-1,5) # Reshaping
        
        contain_target = target[contain].contiguous().view(-1,30)
        box_target = contain_target[:,:10].contiguous().view(-1,5)
        
        # Note that, We assign one predictor to be "responsible" for predicting 
        # an object based on which prediction has the highest current IOU with the ground truth
        # Then, other prediction is "not responsible" for predicting an object
        # That component is included in "contain_noobj_mask variables
        
        contain_obj_mask = torch.cuda.ByteTensor(box_target.size()).zero_().bool() # Create the mask
        contain_noobj_mask = torch.cuda.ByteTensor(box_target.size()).zero_().bool() 
        
        target_iou_gt = torch.zeros(box_target[:,0].size()).cuda() # In order to save the IoU for confidence 
                                                                   # of the cell which contains object
        
        for i in range(0, box_target.size()[0], 2):
            box_p = box_pred[i:i+2] # For 2 bounding boxes information
            box_p_coord = Variable(torch.FloatTensor(box_p.size())) # Box coordinate (x_min, y_min, x_max, y_max)
            box_p_coord[:,:2] =box_p[:, :2]-box_p[:, 2:4]/2 #x_min, y_min ## Fill out
            box_p_coord[:,2:4] =box_p[:, :2]+box_p[:, 2:4]/2 #x_max, y_max ## Fill out
            
            box_t = box_target[i].contiguous().view(-1,5)
            box_t_coord = Variable(torch.FloatTensor(box_t.size()))
            box_t_coord[:,:2] = box_t[:, :2]-box_t[:, 2:4]/2#x_min, y_min ## Fill out
            box_t_coord[:,2:4] = box_t[:, :2]+box_t[:, 2:4]/2#x_max, y_max ## Fill out
            
            iou = self.compute_iou(box_p_coord[:,:4], box_t_coord[:,:4]) # [2,]
                                                      # compute IoU between prediction and target boxes, 
            
            gt_iou, max_idx = iou.max(0)
            contain_obj_mask[i+max_idx] = 1
            contain_noobj_mask[i+1-max_idx] = 1
            
            target_iou_gt[i+max_idx] = gt_iou.data.cuda()
            
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        target_iou_gt = target_iou_gt.to(device)
        
        ## For the cell which contains object
        contain_box_pred =box_pred[contain_obj_mask].contiguous().view(-1,5) ## Fill out 
        
        ## For the cell which does not contain object
        not_contain_box_pred = box_pred[contain_noobj_mask].contiguous().view(-1,5)## Fill out 

        ## For target domain 
        contain_box_target = box_target[contain_obj_mask].contiguous().view(-1,5) ## Fill out
        not_contain_box_target = box_target[contain_noobj_mask].contiguous().view(-1,5) ## Fill out
        not_contain_box_target[:,4] = 0
        
        ## For the GT IoU 
        contain_iou_target = target_iou_gt[contain_obj_mask[:,0]]## Fill out 
        
        obj_loss = F.mse_loss(contain_box_pred[:,4], contain_iou_target, size_average=False)
        xy_loss = F.mse_loss(contain_box_pred[:,:2], contain_box_target[:,:2], size_average=False)
        wh_loss = F.mse_loss(torch.sqrt(contain_box_pred[:,2:4]), torch.sqrt(contain_box_target[:,2:4]), size_average=False)
        noobj_loss2 = F.mse_loss(not_contain_box_pred[:,4], not_contain_box_target[:,4], size_average=False)
        
        return obj_loss, xy_loss, wh_loss, noobj_loss2
        
    def compute_iou(self, box_p, box_t):
        
        pred_area = (box_p[:,2] - box_p[:,0]) * (box_p[:,3] - box_p[:,1]) # [2,]
        target_area = (box_t[:,2] - box_t[:,0]) * (box_t[:,3] - box_t[:,1]) #[1,]
        
        box_p = box_p.unsqueeze(1).expand(2,1,4)
        box_t = box_t.unsqueeze(0).expand(2,1,4)
        
        inter_lt = torch.max(box_p[:,:,:2], box_t[:,:,:2]) # [2,1,2]
        
        inter_rb = torch.min(box_p[:,:,2:], box_t[:,:,2:]) # [2,1,2]
        
        wh = inter_rb - inter_lt # [2,1,2]
        wh[wh<0] = 0 
        
        inter_area = wh[:,:,0] * wh[:,:,1] # [2,1]
        pred_area = pred_area.unsqueeze(1).expand_as(inter_area)
        target_area = target_area.unsqueeze(0).expand_as(inter_area)
        
        iou = inter_area / (pred_area + target_area - inter_area)
        
        return iou
    
        
    
    def forward(self,pred,target):

        batch_size = pred.size()[0]
        
        noobj_loss1 = self.not_contain_obj_error(pred, target)
        prob_loss = self.compute_prob_error(pred, target)
        obj_loss, xy_loss, wh_loss, noobj_loss2 = self.contain_obj_error(pred, target)
        total_loss = (self.l_coord*(xy_loss + wh_loss) + obj_loss + self.l_noobj*(noobj_loss1 + noobj_loss2) + prob_loss)
        
        return total_loss / batch_size

# %% [markdown]
# ### Step 4. Train the model

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
file_root = './dataset-dllab/lab07/all_img/'
train_dataset = YoloDataset(root=file_root, list_file='./misc/lab07/Generate_dataset/voc2007+2012.txt', train=True)
train_loader = DataLoader(train_dataset, batch_size=10, shuffle=True, num_workers=4)

model = YOLO()
state_dict = torch.load('./pretrain/lab07/pre_train.pt')
model.load_state_dict(state_dict['state_dict'])
print('pre_train_complete')

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

learning_rate = 1e-4
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9, weight_decay=5e-4)
optimizer.load_state_dict(state_dict['optimizer'])

criterion = yoloLoss(l_coord=5,l_noobj=0.5)

best = 1e+30
num_epochs = 15
print("training start!")

for epoch in range(num_epochs):
    model.train()
    total_loss = 0
        
    for i, (images, target) in enumerate(train_loader):
        images = images.to(device)
        target = target.to(device)
        
        pred = model(images)
        loss = criterion(pred, target)
        
        total_loss += loss.item()
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if (i+1) % 10 == 0:
            print('Epoch [%d/%d], Iter [%d,%d] Loss:%.4f, average_loss: %.4f' % (epoch+1, num_epochs, i+1, len(train_loader), loss.item(), total_loss / (i+1)))
# Out:
# pre_train_complete
# training start!
# Epoch [1/15], Iter [10,430] Loss:0.6176, average_loss: 0.5295
# Epoch [1/15], Iter [20,430] Loss:0.5951, average_loss: 0.5512
# Epoch [1/15], Iter [30,430] Loss:0.2682, average_loss: 0.5488
# Epoch [1/15], Iter [40,430] Loss:0.6296, average_loss: 0.6138
# Epoch [1/15], Iter [50,430] Loss:0.4608, average_loss: 0.5888
# Epoch [1/15], Iter [60,430] Loss:0.6781, average_loss: 0.5810
# Epoch [1/15], Iter [70,430] Loss:0.8858, average_loss: 0.5875
# Epoch [1/15], Iter [80,430] Loss:0.6028, average_loss: 0.5964
# Epoch [1/15], Iter [90,430] Loss:0.6714, average_loss: 0.5973
# Epoch [1/15], Iter [100,430] Loss:0.5519, average_loss: 0.6076
# Epoch [1/15], Iter [110,430] Loss:0.2751, average_loss: 0.6056
# Epoch [1/15], Iter [120,430] Loss:0.2108, average_loss: 0.5947
# Epoch [1/15], Iter [130,430] Loss:0.7546, average_loss: 0.5893
# Epoch [1/15], Iter [140,430] Loss:0.5400, average_loss: 0.5847
# Epoch [1/15], Iter [150,430] Loss:0.4504, average_loss: 0.5826
# Epoch [1/15], Iter [160,430] Loss:0.5069, average_loss: 0.5804
# Epoch [1/15], Iter [170,430] Loss:0.5816, average_loss: 0.5871
# Epoch [1/15], Iter [180,430] Loss:0.2996, average_loss: 0.5832
# Epoch [1/15], Iter [190,430] Loss:0.5425, average_loss: 0.5798
# Epoch [1/15], Iter [200,430] Loss:0.5572, average_loss: 0.5839
# Epoch [1/15], Iter [210,430] Loss:0.4034, average_loss: 0.5926
# Epoch [1/15], Iter [220,430] Loss:0.4083, average_loss: 0.5917
# Epoch [1/15], Iter [230,430] Loss:0.6890, average_loss: 0.5995
# Epoch [1/15], Iter [240,430] Loss:0.3884, average_loss: 0.5973
# Epoch [1/15], Iter [250,430] Loss:0.4949, average_loss: 0.5962
# Epoch [1/15], Iter [260,430] Loss:0.5618, average_loss: 0.5942
# Epoch [1/15], Iter [270,430] Loss:0.6894, average_loss: 0.5920
# Epoch [1/15], Iter [280,430] Loss:0.8729, average_loss: 0.5912
# Epoch [1/15], Iter [290,430] Loss:1.0356, average_loss: 0.5925
# Epoch [1/15], Iter [300,430] Loss:0.3349, average_loss: 0.5957
# Epoch [1/15], Iter [310,430] Loss:0.2655, average_loss: 0.5955
# Epoch [1/15], Iter [320,430] Loss:0.2583, average_loss: 0.5933
# Epoch [1/15], Iter [330,430] Loss:0.4386, average_loss: 0.5897
# Epoch [1/15], Iter [340,430] Loss:0.7565, average_loss: 0.5895
# Epoch [1/15], Iter [350,430] Loss:0.5200, average_loss: 0.5866
# Epoch [1/15], Iter [360,430] Loss:0.7751, average_loss: 0.5846
# Epoch [1/15], Iter [370,430] Loss:0.5685, average_loss: 0.5876
# Epoch [1/15], Iter [380,430] Loss:1.3081, average_loss: 0.5879
# Epoch [1/15], Iter [390,430] Loss:0.7672, average_loss: 0.5878
# Epoch [1/15], Iter [400,430] Loss:0.4340, average_loss: 0.5846
# Epoch [1/15], Iter [410,430] Loss:0.2174, average_loss: 0.5834
# Epoch [1/15], Iter [420,430] Loss:0.3264, average_loss: 0.5818
# Epoch [1/15], Iter [430,430] Loss:0.4330, average_loss: 0.5812
# Epoch [2/15], Iter [10,430] Loss:0.4428, average_loss: 0.5813
# Epoch [2/15], Iter [20,430] Loss:0.3538, average_loss: 0.5510
# Epoch [2/15], Iter [30,430] Loss:0.4648, average_loss: 0.5579
# Epoch [2/15], Iter [40,430] Loss:0.6302, average_loss: 0.5514
# Epoch [2/15], Iter [50,430] Loss:0.3039, average_loss: 0.5506
# Epoch [2/15], Iter [60,430] Loss:0.6670, average_loss: 0.5512
# Epoch [2/15], Iter [70,430] Loss:0.6713, average_loss: 0.5583
# Epoch [2/15], Iter [80,430] Loss:0.9692, average_loss: 0.5741
# Epoch [2/15], Iter [90,430] Loss:1.1619, average_loss: 0.5705
# Epoch [2/15], Iter [100,430] Loss:1.3056, average_loss: 0.5764
# Epoch [2/15], Iter [110,430] Loss:1.2334, average_loss: 0.5815
# Epoch [2/15], Iter [120,430] Loss:0.7371, average_loss: 0.5841
# Epoch [2/15], Iter [130,430] Loss:0.2953, average_loss: 0.5736
# Epoch [2/15], Iter [140,430] Loss:0.5151, average_loss: 0.5768
# Epoch [2/15], Iter [150,430] Loss:0.6603, average_loss: 0.5745
# Epoch [2/15], Iter [160,430] Loss:0.4844, average_loss: 0.5670
# Epoch [2/15], Iter [170,430] Loss:0.7879, average_loss: 0.5609
# Epoch [2/15], Iter [180,430] Loss:0.8870, average_loss: 0.5655
# Epoch [2/15], Iter [190,430] Loss:0.3560, average_loss: 0.5685
# Epoch [2/15], Iter [200,430] Loss:0.5406, average_loss: 0.5604
# Epoch [2/15], Iter [210,430] Loss:0.2434, average_loss: 0.5582
# Epoch [2/15], Iter [220,430] Loss:0.4658, average_loss: 0.5568
# Epoch [2/15], Iter [230,430] Loss:0.3769, average_loss: 0.5569
# Epoch [2/15], Iter [240,430] Loss:0.4538, average_loss: 0.5583
# Epoch [2/15], Iter [250,430] Loss:0.5277, average_loss: 0.5575
# Epoch [2/15], Iter [260,430] Loss:0.5593, average_loss: 0.5563
# Epoch [2/15], Iter [270,430] Loss:0.3473, average_loss: 0.5558
# Epoch [2/15], Iter [280,430] Loss:0.6231, average_loss: 0.5554
# Epoch [2/15], Iter [290,430] Loss:0.8295, average_loss: 0.5523
# Epoch [2/15], Iter [300,430] Loss:0.3005, average_loss: 0.5508
# Epoch [2/15], Iter [310,430] Loss:0.4183, average_loss: 0.5564
# Epoch [2/15], Iter [320,430] Loss:0.5780, average_loss: 0.5563
# Epoch [2/15], Iter [330,430] Loss:0.5268, average_loss: 0.5565
# Epoch [2/15], Iter [340,430] Loss:0.5848, average_loss: 0.5587
# Epoch [2/15], Iter [350,430] Loss:0.4329, average_loss: 0.5563
# Epoch [2/15], Iter [360,430] Loss:0.3868, average_loss: 0.5564
# Epoch [2/15], Iter [370,430] Loss:0.5376, average_loss: 0.5572
# Epoch [2/15], Iter [380,430] Loss:0.7410, average_loss: 0.5614
# Epoch [2/15], Iter [390,430] Loss:0.3908, average_loss: 0.5635
# Epoch [2/15], Iter [400,430] Loss:0.4078, average_loss: 0.5627
# Epoch [2/15], Iter [410,430] Loss:0.3668, average_loss: 0.5642
# Epoch [2/15], Iter [420,430] Loss:0.6929, average_loss: 0.5676
# Epoch [2/15], Iter [430,430] Loss:0.4992, average_loss: 0.5669
# Epoch [3/15], Iter [10,430] Loss:0.6429, average_loss: 0.6996
# Epoch [3/15], Iter [20,430] Loss:0.3538, average_loss: 0.6221
# Epoch [3/15], Iter [30,430] Loss:0.3434, average_loss: 0.6328
# Epoch [3/15], Iter [40,430] Loss:0.6341, average_loss: 0.6091
# Epoch [3/15], Iter [50,430] Loss:0.5218, average_loss: 0.6100
# Epoch [3/15], Iter [60,430] Loss:0.3035, average_loss: 0.6142
# Epoch [3/15], Iter [70,430] Loss:0.8014, average_loss: 0.5941
# Epoch [3/15], Iter [80,430] Loss:0.5655, average_loss: 0.5821
# Epoch [3/15], Iter [90,430] Loss:0.2328, average_loss: 0.5732
# Epoch [3/15], Iter [100,430] Loss:0.4765, average_loss: 0.5680
# Epoch [3/15], Iter [110,430] Loss:0.5887, average_loss: 0.5609
# Epoch [3/15], Iter [120,430] Loss:0.3373, average_loss: 0.5627
# Epoch [3/15], Iter [130,430] Loss:0.4606, average_loss: 0.5652
# Epoch [3/15], Iter [140,430] Loss:0.5224, average_loss: 0.5652
# Epoch [3/15], Iter [150,430] Loss:0.5760, average_loss: 0.5615
# Epoch [3/15], Iter [160,430] Loss:1.0731, average_loss: 0.5632
# Epoch [3/15], Iter [170,430] Loss:0.3754, average_loss: 0.5606
# Epoch [3/15], Iter [180,430] Loss:0.4413, average_loss: 0.5682
# Epoch [3/15], Iter [190,430] Loss:0.8801, average_loss: 0.5697
# Epoch [3/15], Iter [200,430] Loss:0.3155, average_loss: 0.5613
# Epoch [3/15], Iter [210,430] Loss:0.6260, average_loss: 0.5637
# Epoch [3/15], Iter [220,430] Loss:0.4681, average_loss: 0.5633
# Epoch [3/15], Iter [230,430] Loss:0.5345, average_loss: 0.5674
# Epoch [3/15], Iter [240,430] Loss:0.4308, average_loss: 0.5673
# Epoch [3/15], Iter [250,430] Loss:0.5726, average_loss: 0.5622
# Epoch [3/15], Iter [260,430] Loss:0.4530, average_loss: 0.5632
# Epoch [3/15], Iter [270,430] Loss:0.4198, average_loss: 0.5667
# Epoch [3/15], Iter [280,430] Loss:1.3386, average_loss: 0.5669
# Epoch [3/15], Iter [290,430] Loss:0.4265, average_loss: 0.5636
# Epoch [3/15], Iter [300,430] Loss:1.0067, average_loss: 0.5697
# Epoch [3/15], Iter [310,430] Loss:0.8269, average_loss: 0.5684
# Epoch [3/15], Iter [320,430] Loss:0.8102, average_loss: 0.5687
# Epoch [3/15], Iter [330,430] Loss:0.4763, average_loss: 0.5643
# Epoch [3/15], Iter [340,430] Loss:0.4603, average_loss: 0.5688
# Epoch [3/15], Iter [350,430] Loss:0.3370, average_loss: 0.5664
# Epoch [3/15], Iter [360,430] Loss:0.6363, average_loss: 0.5651
# Epoch [3/15], Iter [370,430] Loss:0.3769, average_loss: 0.5632
# Epoch [3/15], Iter [380,430] Loss:0.3198, average_loss: 0.5617
# Epoch [3/15], Iter [390,430] Loss:0.4765, average_loss: 0.5590
# Epoch [3/15], Iter [400,430] Loss:0.3065, average_loss: 0.5607
# Epoch [3/15], Iter [410,430] Loss:0.3044, average_loss: 0.5624
# Epoch [3/15], Iter [420,430] Loss:0.5003, average_loss: 0.5632
# Epoch [3/15], Iter [430,430] Loss:0.6418, average_loss: 0.5631
# Epoch [4/15], Iter [10,430] Loss:0.4061, average_loss: 0.5373
# Epoch [4/15], Iter [20,430] Loss:0.4861, average_loss: 0.5547
# Epoch [4/15], Iter [30,430] Loss:0.3072, average_loss: 0.5458
# Epoch [4/15], Iter [40,430] Loss:0.4026, average_loss: 0.5499
# Epoch [4/15], Iter [50,430] Loss:0.4963, average_loss: 0.5440
# Epoch [4/15], Iter [60,430] Loss:0.5898, average_loss: 0.5255
# Epoch [4/15], Iter [70,430] Loss:0.5855, average_loss: 0.5252
# Epoch [4/15], Iter [80,430] Loss:0.5773, average_loss: 0.5166
# Epoch [4/15], Iter [90,430] Loss:0.6265, average_loss: 0.5205
# Epoch [4/15], Iter [100,430] Loss:0.4382, average_loss: 0.5323
# Epoch [4/15], Iter [110,430] Loss:0.6973, average_loss: 0.5288
# Epoch [4/15], Iter [120,430] Loss:0.7087, average_loss: 0.5272
# Epoch [4/15], Iter [130,430] Loss:0.3842, average_loss: 0.5307
# Epoch [4/15], Iter [140,430] Loss:0.8753, average_loss: 0.5371
# Epoch [4/15], Iter [150,430] Loss:0.4795, average_loss: 0.5371
# Epoch [4/15], Iter [160,430] Loss:0.2953, average_loss: 0.5378
# Epoch [4/15], Iter [170,430] Loss:0.6983, average_loss: 0.5394
# Epoch [4/15], Iter [180,430] Loss:1.0179, average_loss: 0.5446
# Epoch [4/15], Iter [190,430] Loss:0.3174, average_loss: 0.5450
# Epoch [4/15], Iter [200,430] Loss:0.5753, average_loss: 0.5439
# Epoch [4/15], Iter [210,430] Loss:0.3627, average_loss: 0.5467
# Epoch [4/15], Iter [220,430] Loss:0.6072, average_loss: 0.5475
# Epoch [4/15], Iter [230,430] Loss:0.3709, average_loss: 0.5425
# Epoch [4/15], Iter [240,430] Loss:0.9528, average_loss: 0.5435
# Epoch [4/15], Iter [250,430] Loss:0.2995, average_loss: 0.5453
# Epoch [4/15], Iter [260,430] Loss:0.5100, average_loss: 0.5471
# Epoch [4/15], Iter [270,430] Loss:0.8098, average_loss: 0.5486
# Epoch [4/15], Iter [280,430] Loss:0.7286, average_loss: 0.5495
# Epoch [4/15], Iter [290,430] Loss:0.5706, average_loss: 0.5490
# Epoch [4/15], Iter [300,430] Loss:0.4898, average_loss: 0.5499
# Epoch [4/15], Iter [310,430] Loss:0.4497, average_loss: 0.5491
# Epoch [4/15], Iter [320,430] Loss:0.3491, average_loss: 0.5458
# Epoch [4/15], Iter [330,430] Loss:0.5818, average_loss: 0.5514
# Epoch [4/15], Iter [340,430] Loss:0.6317, average_loss: 0.5522
# Epoch [4/15], Iter [350,430] Loss:0.4053, average_loss: 0.5522
# Epoch [4/15], Iter [360,430] Loss:0.9567, average_loss: 0.5527
# Epoch [4/15], Iter [370,430] Loss:0.8351, average_loss: 0.5538
# Epoch [4/15], Iter [380,430] Loss:0.3635, average_loss: 0.5524
# Epoch [4/15], Iter [390,430] Loss:0.5645, average_loss: 0.5532
# Epoch [4/15], Iter [400,430] Loss:0.7105, average_loss: 0.5510
# Epoch [4/15], Iter [410,430] Loss:0.7010, average_loss: 0.5513
# Epoch [4/15], Iter [420,430] Loss:0.4863, average_loss: 0.5506
# Epoch [4/15], Iter [430,430] Loss:0.3935, average_loss: 0.5483
# Epoch [5/15], Iter [10,430] Loss:0.7153, average_loss: 0.4506
# Epoch [5/15], Iter [20,430] Loss:0.4340, average_loss: 0.5310
# Epoch [5/15], Iter [30,430] Loss:0.6490, average_loss: 0.5409
# Epoch [5/15], Iter [40,430] Loss:0.3892, average_loss: 0.5653
# Epoch [5/15], Iter [50,430] Loss:0.4173, average_loss: 0.5634
# Epoch [5/15], Iter [60,430] Loss:0.5577, average_loss: 0.5392
# Epoch [5/15], Iter [70,430] Loss:0.4194, average_loss: 0.5468
# Epoch [5/15], Iter [80,430] Loss:0.7703, average_loss: 0.5470
# Epoch [5/15], Iter [90,430] Loss:0.3338, average_loss: 0.5385
# Epoch [5/15], Iter [100,430] Loss:0.7029, average_loss: 0.5359
# Epoch [5/15], Iter [110,430] Loss:0.3499, average_loss: 0.5333
# Epoch [5/15], Iter [120,430] Loss:0.4214, average_loss: 0.5272
# Epoch [5/15], Iter [130,430] Loss:0.3712, average_loss: 0.5294
# Epoch [5/15], Iter [140,430] Loss:0.3374, average_loss: 0.5365
# Epoch [5/15], Iter [150,430] Loss:0.2733, average_loss: 0.5347
# Epoch [5/15], Iter [160,430] Loss:0.5688, average_loss: 0.5371
# Epoch [5/15], Iter [170,430] Loss:0.6256, average_loss: 0.5361
# Epoch [5/15], Iter [180,430] Loss:0.3176, average_loss: 0.5398
# Epoch [5/15], Iter [190,430] Loss:0.6039, average_loss: 0.5409
# Epoch [5/15], Iter [200,430] Loss:0.4011, average_loss: 0.5385
# Epoch [5/15], Iter [210,430] Loss:0.5381, average_loss: 0.5370
# Epoch [5/15], Iter [220,430] Loss:0.4419, average_loss: 0.5389
# Epoch [5/15], Iter [230,430] Loss:0.3708, average_loss: 0.5361
# Epoch [5/15], Iter [240,430] Loss:0.3968, average_loss: 0.5331
# Epoch [5/15], Iter [250,430] Loss:0.3435, average_loss: 0.5338
# Epoch [5/15], Iter [260,430] Loss:0.3879, average_loss: 0.5374
# Epoch [5/15], Iter [270,430] Loss:0.4310, average_loss: 0.5356
# Epoch [5/15], Iter [280,430] Loss:0.4542, average_loss: 0.5335
# Epoch [5/15], Iter [290,430] Loss:1.1194, average_loss: 0.5368
# Epoch [5/15], Iter [300,430] Loss:0.2472, average_loss: 0.5345
# Epoch [5/15], Iter [310,430] Loss:0.3218, average_loss: 0.5366
# Epoch [5/15], Iter [320,430] Loss:0.6632, average_loss: 0.5376
# Epoch [5/15], Iter [330,430] Loss:0.2256, average_loss: 0.5389
# Epoch [5/15], Iter [340,430] Loss:0.4886, average_loss: 0.5392
# Epoch [5/15], Iter [350,430] Loss:0.4084, average_loss: 0.5410
# Epoch [5/15], Iter [360,430] Loss:0.7587, average_loss: 0.5425
# Epoch [5/15], Iter [370,430] Loss:0.4643, average_loss: 0.5448
# Epoch [5/15], Iter [380,430] Loss:0.4098, average_loss: 0.5438
# Epoch [5/15], Iter [390,430] Loss:0.4606, average_loss: 0.5424
# Epoch [5/15], Iter [400,430] Loss:0.3632, average_loss: 0.5430
# Epoch [5/15], Iter [410,430] Loss:0.7130, average_loss: 0.5411
# Epoch [5/15], Iter [420,430] Loss:0.4732, average_loss: 0.5417
# Epoch [5/15], Iter [430,430] Loss:0.3099, average_loss: 0.5406
# Epoch [6/15], Iter [10,430] Loss:0.5271, average_loss: 0.4914
# Epoch [6/15], Iter [20,430] Loss:1.2005, average_loss: 0.5673
# Epoch [6/15], Iter [30,430] Loss:0.5471, average_loss: 0.5590
# Epoch [6/15], Iter [40,430] Loss:0.6418, average_loss: 0.5653
# Epoch [6/15], Iter [50,430] Loss:0.7451, average_loss: 0.5532
# Epoch [6/15], Iter [60,430] Loss:0.6910, average_loss: 0.5583
# Epoch [6/15], Iter [70,430] Loss:0.5441, average_loss: 0.5701
# Epoch [6/15], Iter [80,430] Loss:0.4911, average_loss: 0.5565
# Epoch [6/15], Iter [90,430] Loss:0.8256, average_loss: 0.5514
# Epoch [6/15], Iter [100,430] Loss:0.4235, average_loss: 0.5453
# Epoch [6/15], Iter [110,430] Loss:0.4300, average_loss: 0.5346
# Epoch [6/15], Iter [120,430] Loss:0.6346, average_loss: 0.5257
# Epoch [6/15], Iter [130,430] Loss:0.3928, average_loss: 0.5289
# Epoch [6/15], Iter [140,430] Loss:0.6160, average_loss: 0.5294
# Epoch [6/15], Iter [150,430] Loss:0.3670, average_loss: 0.5232
# Epoch [6/15], Iter [160,430] Loss:0.4061, average_loss: 0.5200
# Epoch [6/15], Iter [170,430] Loss:0.4894, average_loss: 0.5236
# Epoch [6/15], Iter [180,430] Loss:0.5169, average_loss: 0.5225
# Epoch [6/15], Iter [190,430] Loss:0.3442, average_loss: 0.5236
# Epoch [6/15], Iter [200,430] Loss:0.4862, average_loss: 0.5192
# Epoch [6/15], Iter [210,430] Loss:0.2814, average_loss: 0.5179
# Epoch [6/15], Iter [220,430] Loss:0.6248, average_loss: 0.5170
# Epoch [6/15], Iter [230,430] Loss:0.4651, average_loss: 0.5124
# Epoch [6/15], Iter [240,430] Loss:0.2904, average_loss: 0.5100
# Epoch [6/15], Iter [250,430] Loss:0.4405, average_loss: 0.5116
# Epoch [6/15], Iter [260,430] Loss:0.3189, average_loss: 0.5103
# Epoch [6/15], Iter [270,430] Loss:0.3176, average_loss: 0.5088
# Epoch [6/15], Iter [280,430] Loss:0.3123, average_loss: 0.5084
# Epoch [6/15], Iter [290,430] Loss:0.3285, average_loss: 0.5072
# Epoch [6/15], Iter [300,430] Loss:1.3018, average_loss: 0.5117
# Epoch [6/15], Iter [310,430] Loss:0.4800, average_loss: 0.5122
# Epoch [6/15], Iter [320,430] Loss:0.3260, average_loss: 0.5114
# Epoch [6/15], Iter [330,430] Loss:0.4626, average_loss: 0.5166
# Epoch [6/15], Iter [340,430] Loss:0.6050, average_loss: 0.5188
# Epoch [6/15], Iter [350,430] Loss:0.3994, average_loss: 0.5178
# Epoch [6/15], Iter [360,430] Loss:0.4440, average_loss: 0.5164
# Epoch [6/15], Iter [370,430] Loss:0.3329, average_loss: 0.5200
# Epoch [6/15], Iter [380,430] Loss:0.3142, average_loss: 0.5198
# Epoch [6/15], Iter [390,430] Loss:0.7085, average_loss: 0.5199
# Epoch [6/15], Iter [400,430] Loss:0.5901, average_loss: 0.5192
# Epoch [6/15], Iter [410,430] Loss:0.3794, average_loss: 0.5190
# Epoch [6/15], Iter [420,430] Loss:0.9781, average_loss: 0.5199
# Epoch [6/15], Iter [430,430] Loss:0.2947, average_loss: 0.5175
# Epoch [7/15], Iter [10,430] Loss:0.3355, average_loss: 0.4363
# Epoch [7/15], Iter [20,430] Loss:0.6903, average_loss: 0.4831
# Epoch [7/15], Iter [30,430] Loss:0.8311, average_loss: 0.5119
# Epoch [7/15], Iter [40,430] Loss:0.3912, average_loss: 0.5222
# Epoch [7/15], Iter [50,430] Loss:0.4111, average_loss: 0.5100
# Epoch [7/15], Iter [60,430] Loss:0.7922, average_loss: 0.5192
# Epoch [7/15], Iter [70,430] Loss:0.3823, average_loss: 0.5061
# Epoch [7/15], Iter [80,430] Loss:0.5213, average_loss: 0.4998
# Epoch [7/15], Iter [90,430] Loss:0.4641, average_loss: 0.5030
# Epoch [7/15], Iter [100,430] Loss:0.4634, average_loss: 0.5072
# Epoch [7/15], Iter [110,430] Loss:0.2373, average_loss: 0.5097
# Epoch [7/15], Iter [120,430] Loss:0.4578, average_loss: 0.5154
# Epoch [7/15], Iter [130,430] Loss:1.0083, average_loss: 0.5187
# Epoch [7/15], Iter [140,430] Loss:0.4378, average_loss: 0.5162
# Epoch [7/15], Iter [150,430] Loss:0.5487, average_loss: 0.5127
# Epoch [7/15], Iter [160,430] Loss:0.6989, average_loss: 0.5147
# Epoch [7/15], Iter [170,430] Loss:0.3750, average_loss: 0.5115
# Epoch [7/15], Iter [180,430] Loss:0.7348, average_loss: 0.5115
# Epoch [7/15], Iter [190,430] Loss:0.6349, average_loss: 0.5154
# Epoch [7/15], Iter [200,430] Loss:0.5073, average_loss: 0.5151
# Epoch [7/15], Iter [210,430] Loss:0.3556, average_loss: 0.5183
# Epoch [7/15], Iter [220,430] Loss:0.3472, average_loss: 0.5132
# Epoch [7/15], Iter [230,430] Loss:0.5466, average_loss: 0.5161
# Epoch [7/15], Iter [240,430] Loss:0.3222, average_loss: 0.5209
# Epoch [7/15], Iter [250,430] Loss:0.3503, average_loss: 0.5230
# Epoch [7/15], Iter [260,430] Loss:0.7368, average_loss: 0.5270
# Epoch [7/15], Iter [270,430] Loss:0.4400, average_loss: 0.5269
# Epoch [7/15], Iter [280,430] Loss:0.6547, average_loss: 0.5281
# Epoch [7/15], Iter [290,430] Loss:0.2250, average_loss: 0.5254
# Epoch [7/15], Iter [300,430] Loss:0.6754, average_loss: 0.5299
# Epoch [7/15], Iter [310,430] Loss:0.4190, average_loss: 0.5311
# Epoch [7/15], Iter [320,430] Loss:0.7846, average_loss: 0.5337
# Epoch [7/15], Iter [330,430] Loss:0.8691, average_loss: 0.5384
# Epoch [7/15], Iter [340,430] Loss:0.6893, average_loss: 0.5386
# Epoch [7/15], Iter [350,430] Loss:0.4567, average_loss: 0.5407
# Epoch [7/15], Iter [360,430] Loss:0.3219, average_loss: 0.5388
# Epoch [7/15], Iter [370,430] Loss:0.3586, average_loss: 0.5360
# Epoch [7/15], Iter [380,430] Loss:0.6524, average_loss: 0.5389
# Epoch [7/15], Iter [390,430] Loss:0.3077, average_loss: 0.5370
# Epoch [7/15], Iter [400,430] Loss:0.4369, average_loss: 0.5350
# Epoch [7/15], Iter [410,430] Loss:0.5110, average_loss: 0.5349
# Epoch [7/15], Iter [420,430] Loss:0.4166, average_loss: 0.5355
# Epoch [7/15], Iter [430,430] Loss:0.4945, average_loss: 0.5355
# Epoch [8/15], Iter [10,430] Loss:0.5176, average_loss: 0.5574
# Epoch [8/15], Iter [20,430] Loss:0.3399, average_loss: 0.5211
# Epoch [8/15], Iter [30,430] Loss:0.4185, average_loss: 0.4905
# Epoch [8/15], Iter [40,430] Loss:0.5891, average_loss: 0.4881
# Epoch [8/15], Iter [50,430] Loss:0.5465, average_loss: 0.4983
# Epoch [8/15], Iter [60,430] Loss:0.3641, average_loss: 0.4995
# Epoch [8/15], Iter [70,430] Loss:0.8007, average_loss: 0.5040
# Epoch [8/15], Iter [80,430] Loss:0.4470, average_loss: 0.5080
# Epoch [8/15], Iter [90,430] Loss:0.8560, average_loss: 0.5245
# Epoch [8/15], Iter [100,430] Loss:0.5363, average_loss: 0.5301
# Epoch [8/15], Iter [110,430] Loss:0.4772, average_loss: 0.5399
# Epoch [8/15], Iter [120,430] Loss:1.0251, average_loss: 0.5402
# Epoch [8/15], Iter [130,430] Loss:0.8196, average_loss: 0.5426
# Epoch [8/15], Iter [140,430] Loss:0.4213, average_loss: 0.5447
# Epoch [8/15], Iter [150,430] Loss:0.3856, average_loss: 0.5355
# Epoch [8/15], Iter [160,430] Loss:0.2684, average_loss: 0.5304
# Epoch [8/15], Iter [170,430] Loss:0.4013, average_loss: 0.5293
# Epoch [8/15], Iter [180,430] Loss:0.2882, average_loss: 0.5281
# Epoch [8/15], Iter [190,430] Loss:0.6184, average_loss: 0.5311
# Epoch [8/15], Iter [200,430] Loss:0.3278, average_loss: 0.5293
# Epoch [8/15], Iter [210,430] Loss:0.5597, average_loss: 0.5292
# Epoch [8/15], Iter [220,430] Loss:0.3616, average_loss: 0.5275
# Epoch [8/15], Iter [230,430] Loss:0.5465, average_loss: 0.5266
# Epoch [8/15], Iter [240,430] Loss:0.4197, average_loss: 0.5271
# Epoch [8/15], Iter [250,430] Loss:0.8234, average_loss: 0.5281
# Epoch [8/15], Iter [260,430] Loss:0.3813, average_loss: 0.5290
# Epoch [8/15], Iter [270,430] Loss:0.3820, average_loss: 0.5297
# Epoch [8/15], Iter [280,430] Loss:0.7221, average_loss: 0.5307
# Epoch [8/15], Iter [290,430] Loss:0.4967, average_loss: 0.5304
# Epoch [8/15], Iter [300,430] Loss:0.4034, average_loss: 0.5305
# Epoch [8/15], Iter [310,430] Loss:0.8009, average_loss: 0.5289
# Epoch [8/15], Iter [320,430] Loss:0.4383, average_loss: 0.5325
# Epoch [8/15], Iter [330,430] Loss:0.5390, average_loss: 0.5342
# Epoch [8/15], Iter [340,430] Loss:0.9252, average_loss: 0.5370
# Epoch [8/15], Iter [350,430] Loss:0.8089, average_loss: 0.5370
# Epoch [8/15], Iter [360,430] Loss:0.3205, average_loss: 0.5353
# Epoch [8/15], Iter [370,430] Loss:0.5839, average_loss: 0.5375
# Epoch [8/15], Iter [380,430] Loss:0.5338, average_loss: 0.5366
# Epoch [8/15], Iter [390,430] Loss:0.8835, average_loss: 0.5364
# Epoch [8/15], Iter [400,430] Loss:0.6728, average_loss: 0.5367
# Epoch [8/15], Iter [410,430] Loss:0.4328, average_loss: 0.5369
# Epoch [8/15], Iter [420,430] Loss:0.3489, average_loss: 0.5360
# Epoch [8/15], Iter [430,430] Loss:0.4279, average_loss: 0.5372
# Epoch [9/15], Iter [10,430] Loss:0.3486, average_loss: 0.5490
# Epoch [9/15], Iter [20,430] Loss:0.4516, average_loss: 0.5640
# Epoch [9/15], Iter [30,430] Loss:0.6943, average_loss: 0.5559
# Epoch [9/15], Iter [40,430] Loss:0.5674, average_loss: 0.5581
# Epoch [9/15], Iter [50,430] Loss:0.4205, average_loss: 0.5776
# Epoch [9/15], Iter [60,430] Loss:0.3304, average_loss: 0.5661
# Epoch [9/15], Iter [70,430] Loss:0.3535, average_loss: 0.5415
# Epoch [9/15], Iter [80,430] Loss:0.4900, average_loss: 0.5447
# Epoch [9/15], Iter [90,430] Loss:0.9480, average_loss: 0.5520
# Epoch [9/15], Iter [100,430] Loss:0.6666, average_loss: 0.5597
# Epoch [9/15], Iter [110,430] Loss:0.3770, average_loss: 0.5605
# Epoch [9/15], Iter [120,430] Loss:0.5151, average_loss: 0.5568
# Epoch [9/15], Iter [130,430] Loss:0.5340, average_loss: 0.5587
# Epoch [9/15], Iter [140,430] Loss:0.2804, average_loss: 0.5669
# Epoch [9/15], Iter [150,430] Loss:0.6141, average_loss: 0.5701
# Epoch [9/15], Iter [160,430] Loss:0.3880, average_loss: 0.5608
# Epoch [9/15], Iter [170,430] Loss:0.5299, average_loss: 0.5592
# Epoch [9/15], Iter [180,430] Loss:0.6202, average_loss: 0.5552
# Epoch [9/15], Iter [190,430] Loss:0.5154, average_loss: 0.5536
# Epoch [9/15], Iter [200,430] Loss:0.4122, average_loss: 0.5497
# Epoch [9/15], Iter [210,430] Loss:0.3596, average_loss: 0.5469
# Epoch [9/15], Iter [220,430] Loss:0.4560, average_loss: 0.5461
# Epoch [9/15], Iter [230,430] Loss:0.4546, average_loss: 0.5493
# Epoch [9/15], Iter [240,430] Loss:0.4809, average_loss: 0.5454
# Epoch [9/15], Iter [250,430] Loss:0.3751, average_loss: 0.5485
# Epoch [9/15], Iter [260,430] Loss:0.3631, average_loss: 0.5462
# Epoch [9/15], Iter [270,430] Loss:0.4945, average_loss: 0.5434
# Epoch [9/15], Iter [280,430] Loss:0.4119, average_loss: 0.5423
# Epoch [9/15], Iter [290,430] Loss:0.4227, average_loss: 0.5415
# Epoch [9/15], Iter [300,430] Loss:0.5191, average_loss: 0.5423
# Epoch [9/15], Iter [310,430] Loss:0.6498, average_loss: 0.5407
# Epoch [9/15], Iter [320,430] Loss:0.9116, average_loss: 0.5410
# Epoch [9/15], Iter [330,430] Loss:0.4597, average_loss: 0.5407
# Epoch [9/15], Iter [340,430] Loss:0.4881, average_loss: 0.5382
# Epoch [9/15], Iter [350,430] Loss:0.9793, average_loss: 0.5399
# Epoch [9/15], Iter [360,430] Loss:0.8321, average_loss: 0.5445
# Epoch [9/15], Iter [370,430] Loss:0.3411, average_loss: 0.5427
# Epoch [9/15], Iter [380,430] Loss:0.5559, average_loss: 0.5425
# Epoch [9/15], Iter [390,430] Loss:0.7242, average_loss: 0.5435
# Epoch [9/15], Iter [400,430] Loss:0.4730, average_loss: 0.5420
# Epoch [9/15], Iter [410,430] Loss:0.6278, average_loss: 0.5415
# Epoch [9/15], Iter [420,430] Loss:0.3551, average_loss: 0.5415
# Epoch [9/15], Iter [430,430] Loss:0.7831, average_loss: 0.5407
# Epoch [10/15], Iter [10,430] Loss:0.2770, average_loss: 0.6228
# Epoch [10/15], Iter [20,430] Loss:0.5281, average_loss: 0.5473
# Epoch [10/15], Iter [30,430] Loss:0.4906, average_loss: 0.5584
# Epoch [10/15], Iter [40,430] Loss:0.6794, average_loss: 0.5300
# Epoch [10/15], Iter [50,430] Loss:0.5212, average_loss: 0.5031
# Epoch [10/15], Iter [60,430] Loss:0.7687, average_loss: 0.5032
# Epoch [10/15], Iter [70,430] Loss:0.4653, average_loss: 0.4893
# Epoch [10/15], Iter [80,430] Loss:0.4841, average_loss: 0.4895
# Epoch [10/15], Iter [90,430] Loss:0.5207, average_loss: 0.4998
# Epoch [10/15], Iter [100,430] Loss:0.5347, average_loss: 0.4993
# Epoch [10/15], Iter [110,430] Loss:0.3999, average_loss: 0.5041
# Epoch [10/15], Iter [120,430] Loss:0.4861, average_loss: 0.5107
# Epoch [10/15], Iter [130,430] Loss:0.8042, average_loss: 0.5132
# Epoch [10/15], Iter [140,430] Loss:0.5884, average_loss: 0.5115
# Epoch [10/15], Iter [150,430] Loss:0.5454, average_loss: 0.5100
# Epoch [10/15], Iter [160,430] Loss:1.1793, average_loss: 0.5190
# Epoch [10/15], Iter [170,430] Loss:0.5497, average_loss: 0.5231
# Epoch [10/15], Iter [180,430] Loss:0.4716, average_loss: 0.5273
# Epoch [10/15], Iter [190,430] Loss:0.4785, average_loss: 0.5317
# Epoch [10/15], Iter [200,430] Loss:0.8619, average_loss: 0.5310
# Epoch [10/15], Iter [210,430] Loss:0.5971, average_loss: 0.5305
# Epoch [10/15], Iter [220,430] Loss:0.6048, average_loss: 0.5265
# Epoch [10/15], Iter [230,430] Loss:0.3465, average_loss: 0.5228
# Epoch [10/15], Iter [240,430] Loss:0.2570, average_loss: 0.5209
# Epoch [10/15], Iter [250,430] Loss:0.4679, average_loss: 0.5237
# Epoch [10/15], Iter [260,430] Loss:0.6462, average_loss: 0.5248
# Epoch [10/15], Iter [270,430] Loss:0.3942, average_loss: 0.5244
# Epoch [10/15], Iter [280,430] Loss:0.3514, average_loss: 0.5229
# Epoch [10/15], Iter [290,430] Loss:0.3543, average_loss: 0.5222
# Epoch [10/15], Iter [300,430] Loss:0.7059, average_loss: 0.5249
# Epoch [10/15], Iter [310,430] Loss:0.3794, average_loss: 0.5253
# Epoch [10/15], Iter [320,430] Loss:0.5682, average_loss: 0.5255
# Epoch [10/15], Iter [330,430] Loss:0.4000, average_loss: 0.5278
# Epoch [10/15], Iter [340,430] Loss:1.1388, average_loss: 0.5291
# Epoch [10/15], Iter [350,430] Loss:0.2231, average_loss: 0.5263
# Epoch [10/15], Iter [360,430] Loss:0.6950, average_loss: 0.5259
# Epoch [10/15], Iter [370,430] Loss:0.4277, average_loss: 0.5285
# Epoch [10/15], Iter [380,430] Loss:0.3933, average_loss: 0.5280
# Epoch [10/15], Iter [390,430] Loss:0.3871, average_loss: 0.5283
# Epoch [10/15], Iter [400,430] Loss:0.2678, average_loss: 0.5274
# Epoch [10/15], Iter [410,430] Loss:0.8278, average_loss: 0.5273
# Epoch [10/15], Iter [420,430] Loss:0.5994, average_loss: 0.5269
# Epoch [10/15], Iter [430,430] Loss:0.6745, average_loss: 0.5255
# Epoch [11/15], Iter [10,430] Loss:0.5220, average_loss: 0.5219
# Epoch [11/15], Iter [20,430] Loss:0.5979, average_loss: 0.5364
# Epoch [11/15], Iter [30,430] Loss:0.3424, average_loss: 0.5095
# Epoch [11/15], Iter [40,430] Loss:0.4945, average_loss: 0.5142
# Epoch [11/15], Iter [50,430] Loss:0.4154, average_loss: 0.5164
# Epoch [11/15], Iter [60,430] Loss:0.5267, average_loss: 0.5064
# Epoch [11/15], Iter [70,430] Loss:0.7232, average_loss: 0.5119
# Epoch [11/15], Iter [80,430] Loss:0.3751, average_loss: 0.5116
# Epoch [11/15], Iter [90,430] Loss:0.9128, average_loss: 0.5157
# Epoch [11/15], Iter [100,430] Loss:0.5730, average_loss: 0.5086
# Epoch [11/15], Iter [110,430] Loss:0.6422, average_loss: 0.5122
# Epoch [11/15], Iter [120,430] Loss:0.9083, average_loss: 0.5172
# Epoch [11/15], Iter [130,430] Loss:0.6162, average_loss: 0.5165
# Epoch [11/15], Iter [140,430] Loss:0.6974, average_loss: 0.5193
# Epoch [11/15], Iter [150,430] Loss:0.4881, average_loss: 0.5192
# Epoch [11/15], Iter [160,430] Loss:0.5038, average_loss: 0.5224
# Epoch [11/15], Iter [170,430] Loss:0.3442, average_loss: 0.5205
# Epoch [11/15], Iter [180,430] Loss:0.5750, average_loss: 0.5251
# Epoch [11/15], Iter [190,430] Loss:0.2599, average_loss: 0.5273
# Epoch [11/15], Iter [200,430] Loss:0.2697, average_loss: 0.5233
# Epoch [11/15], Iter [210,430] Loss:0.5185, average_loss: 0.5217
# Epoch [11/15], Iter [220,430] Loss:0.4711, average_loss: 0.5223
# Epoch [11/15], Iter [230,430] Loss:0.2928, average_loss: 0.5179
# Epoch [11/15], Iter [240,430] Loss:0.4608, average_loss: 0.5149
# Epoch [11/15], Iter [250,430] Loss:0.4698, average_loss: 0.5171
# Epoch [11/15], Iter [260,430] Loss:0.4661, average_loss: 0.5197
# Epoch [11/15], Iter [270,430] Loss:0.4832, average_loss: 0.5168
# Epoch [11/15], Iter [280,430] Loss:0.5279, average_loss: 0.5162
# Epoch [11/15], Iter [290,430] Loss:0.4747, average_loss: 0.5191
# Epoch [11/15], Iter [300,430] Loss:0.3574, average_loss: 0.5180
# Epoch [11/15], Iter [310,430] Loss:0.3369, average_loss: 0.5177
# Epoch [11/15], Iter [320,430] Loss:0.8228, average_loss: 0.5149
# Epoch [11/15], Iter [330,430] Loss:0.4412, average_loss: 0.5150
# Epoch [11/15], Iter [340,430] Loss:0.2757, average_loss: 0.5148
# Epoch [11/15], Iter [350,430] Loss:0.3450, average_loss: 0.5154
# Epoch [11/15], Iter [360,430] Loss:0.2808, average_loss: 0.5132
# Epoch [11/15], Iter [370,430] Loss:0.4648, average_loss: 0.5139
# Epoch [11/15], Iter [380,430] Loss:0.4705, average_loss: 0.5144
# Epoch [11/15], Iter [390,430] Loss:0.4883, average_loss: 0.5130
# Epoch [11/15], Iter [400,430] Loss:0.3416, average_loss: 0.5118
# Epoch [11/15], Iter [410,430] Loss:0.5301, average_loss: 0.5122
# Epoch [11/15], Iter [420,430] Loss:0.5750, average_loss: 0.5124
# Epoch [11/15], Iter [430,430] Loss:0.5552, average_loss: 0.5125
# Epoch [12/15], Iter [10,430] Loss:0.6863, average_loss: 0.4046
# Epoch [12/15], Iter [20,430] Loss:0.4224, average_loss: 0.4713
# Epoch [12/15], Iter [30,430] Loss:0.3931, average_loss: 0.4723
# Epoch [12/15], Iter [40,430] Loss:0.6990, average_loss: 0.4978
# Epoch [12/15], Iter [50,430] Loss:0.2689, average_loss: 0.5035
# Epoch [12/15], Iter [60,430] Loss:0.2794, average_loss: 0.4914
# Epoch [12/15], Iter [70,430] Loss:0.3255, average_loss: 0.4979
# Epoch [12/15], Iter [80,430] Loss:0.4872, average_loss: 0.4966
# Epoch [12/15], Iter [90,430] Loss:1.0403, average_loss: 0.4984
# Epoch [12/15], Iter [100,430] Loss:0.5109, average_loss: 0.5024
# Epoch [12/15], Iter [110,430] Loss:0.3291, average_loss: 0.4965
# Epoch [12/15], Iter [120,430] Loss:0.7530, average_loss: 0.5011
# Epoch [12/15], Iter [130,430] Loss:0.8869, average_loss: 0.5116
# Epoch [12/15], Iter [140,430] Loss:1.0066, average_loss: 0.5162
# Epoch [12/15], Iter [150,430] Loss:0.6588, average_loss: 0.5130
# Epoch [12/15], Iter [160,430] Loss:0.4410, average_loss: 0.5128
# Epoch [12/15], Iter [170,430] Loss:0.5579, average_loss: 0.5156
# Epoch [12/15], Iter [180,430] Loss:0.3759, average_loss: 0.5216
# Epoch [12/15], Iter [190,430] Loss:0.4407, average_loss: 0.5217
# Epoch [12/15], Iter [200,430] Loss:0.3728, average_loss: 0.5194
# Epoch [12/15], Iter [210,430] Loss:0.5457, average_loss: 0.5162
# Epoch [12/15], Iter [220,430] Loss:0.5566, average_loss: 0.5202
# Epoch [12/15], Iter [230,430] Loss:0.9486, average_loss: 0.5257
# Epoch [12/15], Iter [240,430] Loss:0.4414, average_loss: 0.5269
# Epoch [12/15], Iter [250,430] Loss:0.7870, average_loss: 0.5284
# Epoch [12/15], Iter [260,430] Loss:0.6175, average_loss: 0.5308
# Epoch [12/15], Iter [270,430] Loss:0.9948, average_loss: 0.5385
# Epoch [12/15], Iter [280,430] Loss:0.5698, average_loss: 0.5397
# Epoch [12/15], Iter [290,430] Loss:0.5872, average_loss: 0.5395
# Epoch [12/15], Iter [300,430] Loss:0.5384, average_loss: 0.5363
# Epoch [12/15], Iter [310,430] Loss:0.5263, average_loss: 0.5365
# Epoch [12/15], Iter [320,430] Loss:0.4114, average_loss: 0.5339
# Epoch [12/15], Iter [330,430] Loss:0.4659, average_loss: 0.5364
# Epoch [12/15], Iter [340,430] Loss:0.5163, average_loss: 0.5356
# Epoch [12/15], Iter [350,430] Loss:0.8973, average_loss: 0.5347
# Epoch [12/15], Iter [360,430] Loss:0.4919, average_loss: 0.5349
# Epoch [12/15], Iter [370,430] Loss:0.6545, average_loss: 0.5339
# Epoch [12/15], Iter [380,430] Loss:0.4613, average_loss: 0.5346
# Epoch [12/15], Iter [390,430] Loss:0.6804, average_loss: 0.5345
# Epoch [12/15], Iter [400,430] Loss:0.9777, average_loss: 0.5379
# Epoch [12/15], Iter [410,430] Loss:0.7342, average_loss: 0.5374
# Epoch [12/15], Iter [420,430] Loss:0.7647, average_loss: 0.5351
# Epoch [12/15], Iter [430,430] Loss:0.3417, average_loss: 0.5360
# Epoch [13/15], Iter [10,430] Loss:0.3290, average_loss: 0.4751
# Epoch [13/15], Iter [20,430] Loss:0.6303, average_loss: 0.5568
# Epoch [13/15], Iter [30,430] Loss:0.5428, average_loss: 0.5786
# Epoch [13/15], Iter [40,430] Loss:0.4915, average_loss: 0.5783
# Epoch [13/15], Iter [50,430] Loss:0.3501, average_loss: 0.5706
# Epoch [13/15], Iter [60,430] Loss:0.4433, average_loss: 0.5509
# Epoch [13/15], Iter [70,430] Loss:0.5746, average_loss: 0.5422
# Epoch [13/15], Iter [80,430] Loss:0.5420, average_loss: 0.5297
# Epoch [13/15], Iter [90,430] Loss:0.3330, average_loss: 0.5203
# Epoch [13/15], Iter [100,430] Loss:0.7411, average_loss: 0.5214
# Epoch [13/15], Iter [110,430] Loss:0.4542, average_loss: 0.5266
# Epoch [13/15], Iter [120,430] Loss:0.3075, average_loss: 0.5164
# Epoch [13/15], Iter [130,430] Loss:0.5393, average_loss: 0.5163
# Epoch [13/15], Iter [140,430] Loss:0.4751, average_loss: 0.5150
# Epoch [13/15], Iter [150,430] Loss:0.5707, average_loss: 0.5105
# Epoch [13/15], Iter [160,430] Loss:0.5125, average_loss: 0.5097
# Epoch [13/15], Iter [170,430] Loss:0.3864, average_loss: 0.5070
# Epoch [13/15], Iter [180,430] Loss:0.4422, average_loss: 0.5091
# Epoch [13/15], Iter [190,430] Loss:0.6204, average_loss: 0.5090
# Epoch [13/15], Iter [200,430] Loss:0.2399, average_loss: 0.5124
# Epoch [13/15], Iter [210,430] Loss:0.2293, average_loss: 0.5114
# Epoch [13/15], Iter [220,430] Loss:0.3774, average_loss: 0.5075
# Epoch [13/15], Iter [230,430] Loss:0.7466, average_loss: 0.5077
# Epoch [13/15], Iter [240,430] Loss:0.3669, average_loss: 0.5083
# Epoch [13/15], Iter [250,430] Loss:0.2551, average_loss: 0.5051
# Epoch [13/15], Iter [260,430] Loss:0.5716, average_loss: 0.5079
# Epoch [13/15], Iter [270,430] Loss:0.4082, average_loss: 0.5060
# Epoch [13/15], Iter [280,430] Loss:0.4976, average_loss: 0.5075
# Epoch [13/15], Iter [290,430] Loss:0.5199, average_loss: 0.5082
# Epoch [13/15], Iter [300,430] Loss:0.4019, average_loss: 0.5084
# Epoch [13/15], Iter [310,430] Loss:0.4590, average_loss: 0.5078
# Epoch [13/15], Iter [320,430] Loss:0.4622, average_loss: 0.5110
# Epoch [13/15], Iter [330,430] Loss:0.4861, average_loss: 0.5144
# Epoch [13/15], Iter [340,430] Loss:0.4013, average_loss: 0.5163
# Epoch [13/15], Iter [350,430] Loss:0.5088, average_loss: 0.5165
# Epoch [13/15], Iter [360,430] Loss:0.8218, average_loss: 0.5173
# Epoch [13/15], Iter [370,430] Loss:0.5720, average_loss: 0.5185
# Epoch [13/15], Iter [380,430] Loss:0.3400, average_loss: 0.5174
# Epoch [13/15], Iter [390,430] Loss:0.5440, average_loss: 0.5181
# Epoch [13/15], Iter [400,430] Loss:0.5427, average_loss: 0.5169
# Epoch [13/15], Iter [410,430] Loss:0.4545, average_loss: 0.5196
# Epoch [13/15], Iter [420,430] Loss:0.3013, average_loss: 0.5203
# Epoch [13/15], Iter [430,430] Loss:0.4223, average_loss: 0.5218
# Epoch [14/15], Iter [10,430] Loss:0.5963, average_loss: 0.5750
# Epoch [14/15], Iter [20,430] Loss:0.9744, average_loss: 0.5943
# Epoch [14/15], Iter [30,430] Loss:0.5947, average_loss: 0.5744
# Epoch [14/15], Iter [40,430] Loss:0.9362, average_loss: 0.5734
# Epoch [14/15], Iter [50,430] Loss:0.5045, average_loss: 0.5521
# Epoch [14/15], Iter [60,430] Loss:0.4340, average_loss: 0.5402
# Epoch [14/15], Iter [70,430] Loss:0.9151, average_loss: 0.5315
# Epoch [14/15], Iter [80,430] Loss:0.7398, average_loss: 0.5256
# Epoch [14/15], Iter [90,430] Loss:0.3033, average_loss: 0.5185
# Epoch [14/15], Iter [100,430] Loss:0.7912, average_loss: 0.5227
# Epoch [14/15], Iter [110,430] Loss:0.4258, average_loss: 0.5311
# Epoch [14/15], Iter [120,430] Loss:0.3484, average_loss: 0.5340
# Epoch [14/15], Iter [130,430] Loss:0.4739, average_loss: 0.5331
# Epoch [14/15], Iter [140,430] Loss:0.6596, average_loss: 0.5285
# Epoch [14/15], Iter [150,430] Loss:0.6337, average_loss: 0.5251
# Epoch [14/15], Iter [160,430] Loss:0.6670, average_loss: 0.5218
# Epoch [14/15], Iter [170,430] Loss:0.4277, average_loss: 0.5248
# Epoch [14/15], Iter [180,430] Loss:0.6148, average_loss: 0.5249
# Epoch [14/15], Iter [190,430] Loss:0.5150, average_loss: 0.5250
# Epoch [14/15], Iter [200,430] Loss:0.9042, average_loss: 0.5258
# Epoch [14/15], Iter [210,430] Loss:0.3137, average_loss: 0.5241
# Epoch [14/15], Iter [220,430] Loss:0.4606, average_loss: 0.5246
# Epoch [14/15], Iter [230,430] Loss:0.4535, average_loss: 0.5238
# Epoch [14/15], Iter [240,430] Loss:0.4452, average_loss: 0.5236
# Epoch [14/15], Iter [250,430] Loss:1.0562, average_loss: 0.5299
# Epoch [14/15], Iter [260,430] Loss:0.6298, average_loss: 0.5307
# Epoch [14/15], Iter [270,430] Loss:0.5317, average_loss: 0.5360
# Epoch [14/15], Iter [280,430] Loss:0.4829, average_loss: 0.5344
# Epoch [14/15], Iter [290,430] Loss:0.3267, average_loss: 0.5340
# Epoch [14/15], Iter [300,430] Loss:0.4272, average_loss: 0.5327
# Epoch [14/15], Iter [310,430] Loss:0.5445, average_loss: 0.5327
# Epoch [14/15], Iter [320,430] Loss:0.8220, average_loss: 0.5324
# Epoch [14/15], Iter [330,430] Loss:0.7927, average_loss: 0.5333
# Epoch [14/15], Iter [340,430] Loss:0.3706, average_loss: 0.5312
# Epoch [14/15], Iter [350,430] Loss:0.5998, average_loss: 0.5310
# Epoch [14/15], Iter [360,430] Loss:0.4278, average_loss: 0.5293
# Epoch [14/15], Iter [370,430] Loss:0.3418, average_loss: 0.5296
# Epoch [14/15], Iter [380,430] Loss:0.4933, average_loss: 0.5292
# Epoch [14/15], Iter [390,430] Loss:0.8444, average_loss: 0.5311
# Epoch [14/15], Iter [400,430] Loss:0.3645, average_loss: 0.5309
# Epoch [14/15], Iter [410,430] Loss:0.5870, average_loss: 0.5312
# Epoch [14/15], Iter [420,430] Loss:0.5649, average_loss: 0.5323
# Epoch [14/15], Iter [430,430] Loss:0.3428, average_loss: 0.5326
# Epoch [15/15], Iter [10,430] Loss:0.5042, average_loss: 0.5797
# Epoch [15/15], Iter [20,430] Loss:0.8115, average_loss: 0.5798
# Epoch [15/15], Iter [30,430] Loss:0.7933, average_loss: 0.5543
# Epoch [15/15], Iter [40,430] Loss:0.4428, average_loss: 0.5164
# Epoch [15/15], Iter [50,430] Loss:0.5037, average_loss: 0.5196
# Epoch [15/15], Iter [60,430] Loss:0.4961, average_loss: 0.5106
# Epoch [15/15], Iter [70,430] Loss:0.2696, average_loss: 0.5108
# Epoch [15/15], Iter [80,430] Loss:0.7312, average_loss: 0.5097
# Epoch [15/15], Iter [90,430] Loss:0.4252, average_loss: 0.5010
# Epoch [15/15], Iter [100,430] Loss:0.4192, average_loss: 0.5099
# Epoch [15/15], Iter [110,430] Loss:0.6367, average_loss: 0.5108
# Epoch [15/15], Iter [120,430] Loss:0.5263, average_loss: 0.5079
# Epoch [15/15], Iter [130,430] Loss:0.4296, average_loss: 0.5100
# Epoch [15/15], Iter [140,430] Loss:0.5552, average_loss: 0.5147
# Epoch [15/15], Iter [150,430] Loss:0.3769, average_loss: 0.5107
# Epoch [15/15], Iter [160,430] Loss:0.5167, average_loss: 0.5080
# Epoch [15/15], Iter [170,430] Loss:0.3174, average_loss: 0.5093
# Epoch [15/15], Iter [180,430] Loss:0.4658, average_loss: 0.5080
# Epoch [15/15], Iter [190,430] Loss:0.6435, average_loss: 0.5098
# Epoch [15/15], Iter [200,430] Loss:0.2408, average_loss: 0.5095
# Epoch [15/15], Iter [210,430] Loss:0.3973, average_loss: 0.5103
# Epoch [15/15], Iter [220,430] Loss:0.9987, average_loss: 0.5125
# Epoch [15/15], Iter [230,430] Loss:0.2682, average_loss: 0.5151
# Epoch [15/15], Iter [240,430] Loss:0.3544, average_loss: 0.5141
# Epoch [15/15], Iter [250,430] Loss:0.2945, average_loss: 0.5136
# Epoch [15/15], Iter [260,430] Loss:0.4015, average_loss: 0.5109
# Epoch [15/15], Iter [270,430] Loss:0.8732, average_loss: 0.5143
# Epoch [15/15], Iter [280,430] Loss:0.5457, average_loss: 0.5179
# Epoch [15/15], Iter [290,430] Loss:0.2892, average_loss: 0.5170
# Epoch [15/15], Iter [300,430] Loss:0.2932, average_loss: 0.5129
# Epoch [15/15], Iter [310,430] Loss:0.5893, average_loss: 0.5159
# Epoch [15/15], Iter [320,430] Loss:0.6223, average_loss: 0.5189
# Epoch [15/15], Iter [330,430] Loss:0.4820, average_loss: 0.5171
# Epoch [15/15], Iter [340,430] Loss:0.4982, average_loss: 0.5197
# Epoch [15/15], Iter [350,430] Loss:0.2701, average_loss: 0.5184
# Epoch [15/15], Iter [360,430] Loss:0.4887, average_loss: 0.5197
# Epoch [15/15], Iter [370,430] Loss:0.4473, average_loss: 0.5209
# Epoch [15/15], Iter [380,430] Loss:0.3496, average_loss: 0.5204
# Epoch [15/15], Iter [390,430] Loss:0.4717, average_loss: 0.5205
# Epoch [15/15], Iter [400,430] Loss:0.5479, average_loss: 0.5229
# Epoch [15/15], Iter [410,430] Loss:0.3993, average_loss: 0.5230
# Epoch [15/15], Iter [420,430] Loss:0.3961, average_loss: 0.5203
# Epoch [15/15], Iter [430,430] Loss:0.6559, average_loss: 0.5217

# %% [markdown]
# ### Step 5. Inference

# %% [markdown]
# ### Step 5-1. Inference (Visualizing)
# - The below code is for visualizing your results.
# - Check out!

# %%
## Visualizing the bouding box image
from misc.lab07.util import *

SMALL_VOC_CLASSES = ('aeroplane', 'bicycle', 'bus', 'car', 'cat', 'dog')

Color = [[0, 0, 0],
                    [128, 0, 0],
                    [0, 128, 0],
                    [128, 128, 0],
                    [0, 0, 128],
                    [128, 0, 128]]

def visualize(model, path):
    result = []
    image = cv2.imread(path)
    h, w, _ = image.shape
    img = cv2.resize(image, (448, 448))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    transform = transforms.Compose([transforms.ToTensor(),])
    img = 2 * transform(img) - 1
    img = Variable(img[None,:,:,:],volatile=True)
    img = img.cuda()
    
    pred = model(img) #1x7x7x30
    pred = pred.cpu()
    boxes,cls_indexs,probs =  interpret_target(pred, 0.1)
    
    for i, box in enumerate(boxes):
        
        x1 = max(int(box[0] * w), 0)
        x2 = min(int(box[2] * w), w)
        y1 = max(int(box[1] * h), 0)
        y2 = min(int(box[3] * h), h)
        cls_index = cls_indexs[i]
        cls_index = int(cls_index)
        prob = probs[i]
        prob = float(prob)
        result.append([(x1, y1), (x2, y2), SMALL_VOC_CLASSES[cls_index], prob])
        
    img = np.zeros((h, w, 3), np.bool)
    img = img + image[:,:,::-1]
        
    for left_up,right_bottom,class_name,prob in result:
        color = Color[SMALL_VOC_CLASSES.index(class_name)]
        cv2.rectangle(img, left_up, right_bottom, color, 2)
        label = class_name+str(round(prob,2))
        text_size, baseline = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.4, 1)
        p1 = (left_up[0], left_up[1]- text_size[1])
        cv2.rectangle(img, (p1[0] - 2//2, p1[1] - 2 - baseline), (p1[0] + text_size[0], p1[1] + text_size[1]), color, -1)
        cv2.putText(img, label, (p1[0], p1[1] + baseline), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (255,255,255), 1, 8)
    
    print(label)
    plt.imshow(img)
    
model.eval()
# Out:
# YOLO(
#   (pre_train_net): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#     (1): LeakyReLU(negative_slope=0.01, inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): LeakyReLU(negative_slope=0.01, inplace=True)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1))
#     (7): LeakyReLU(negative_slope=0.01, inplace=True)
#     (8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): LeakyReLU(negative_slope=0.01, inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (11): LeakyReLU(negative_slope=0.01, inplace=True)
#     (12): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): LeakyReLU(negative_slope=0.01, inplace=True)
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (16): LeakyReLU(negative_slope=0.01, inplace=True)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): LeakyReLU(negative_slope=0.01, inplace=True)
#     (19): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (20): LeakyReLU(negative_slope=0.01, inplace=True)
#     (21): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): LeakyReLU(negative_slope=0.01, inplace=True)
#     (23): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (24): LeakyReLU(negative_slope=0.01, inplace=True)
#     (25): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): LeakyReLU(negative_slope=0.01, inplace=True)
#     (27): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (28): LeakyReLU(negative_slope=0.01, inplace=True)
#     (29): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (30): LeakyReLU(negative_slope=0.01, inplace=True)
#     (31): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#     (32): LeakyReLU(negative_slope=0.01, inplace=True)
#     (33): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (34): LeakyReLU(negative_slope=0.01, inplace=True)
#     (35): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (36): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#     (37): LeakyReLU(negative_slope=0.01, inplace=True)
#     (38): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (39): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (post_net): Sequential(
#     (0): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.01, inplace=True)
#     (2): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (3): LeakyReLU(negative_slope=0.01, inplace=True)
#     (4): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): LeakyReLU(negative_slope=0.01, inplace=True)
#     (6): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (FC1): Sequential(
#     (0): Linear(in_features=50176, out_features=4096, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Dropout(p=0.5, inplace=False)
#   )
#   (FC2): Sequential(
#     (0): Linear(in_features=4096, out_features=1470, bias=True)
#   )
# )

# %% [markdown]
# - You can check various results by chaning the name of files.

# %%
visualize(model, './misc/lab07/Generate_dataset/images/004199.jpg')
# Out:
# aeroplane0.51

# %%
visualize(model, './misc/lab07/Generate_dataset/images/006034.jpg')
# Out:
# car0.62

# %% [markdown]
# ### Step 6-2. Inference (mAP)
# - The below code is for checkout your network performance,
# - By using this code, your network prediction is saved in Generate_dataset directory
# - Then, %run ./misc/lab07/Generate_dataset/main.py
# - After a few seconds, the mAP is printed.
# - **Note that if your code is correct, the mAP will be over 69.**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

SMALL_VOC_CLASSES = ('aeroplane', 'bicycle', 'bus', 'car', 'cat', 'dog')
os.makedirs('predicted', exist_ok=True)

def write(model, path):
    result = []
    image = cv2.imread(path)
    h, w, _ = image.shape
    img = cv2.resize(image, (448, 448))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    transform = transforms.Compose([transforms.ToTensor(),])
    img = 2 * transform(img) - 1
    img = Variable(img[None,:,:,:],volatile=True)
    img = img.cuda()
    
    pred = model(img) #1x7x7x30
    pred = pred.cpu()
    boxes,cls_indexs,probs =  interpret_target(pred, 0)
    
    
    txt_file = open(os.path.join('predicted', os.path.basename(path)[:-4]+'.txt'), 'w')
    
    for i, box in enumerate(boxes):
        
        x1 = max(int(box[0] * w), 0)
        x2 = min(int(box[2] * w), w)
        y1 = max(int(box[1] * h), 0)
        y2 = min(int(box[3] * h), h)
        cls_index = cls_indexs[i]
        cls_index = int(cls_index)
        prob = probs[i]
        prob = float(prob)
        txt_file.write(str(SMALL_VOC_CLASSES[cls_index])+' '+'%.6f'%(prob)+' '+str(x1)+' '+str(y1)+' '+str(x2)+' '+str(y2))
        txt_file.write('\n')
    txt_file.close()
    
import glob

model.eval()
img_names = glob.glob('./misc/lab07/Generate_dataset/images/*')

for i, file_name in enumerate(img_names):
    write(model, file_name)
    if i % 500 == 0:
        print(i)
# Out:
# 0
# 500
# 1000

# %%
# %run ./misc/lab07/Generate_dataset/main.py
# Out:
# 64.83% = aeroplane AP
# 66.99% = bicycle AP
# 64.95% = bus AP
# 68.24% = car AP
# 72.64% = cat AP
# 77.90% = dog AP
# mAP = 69.26%

# %% [markdown]
# ### *Discussion*
#
# YOLO는  one-stage detection 방법으로, 이미지를 여러개로 나누어서 분석하는 것이 아니라 이미지를 전체를 한번만 보고 object detection을 수행한다. 따라서 정확도는 조금 떨어질지 몰라도 속도가 빨라서 real-time으로도 사용할 수 있다. 한 가지 특이한 점은, object detection을 regression problem으로 보고 bounding box를 regress한다는 것이다.
#
# 결과를 보면 마지막 epoch에 대한 평균 loss는 0.5217이다. mIOU는 69.26%로 주어진 조건을 만족한다.
#
# 이번에는 상당히 많은 부분에서 코드가 주어지고, 적은 부분만 채워넣으면 됐다. 그러나, 전체적인 코드를 이해해야 코드를 채워넣을 수 있었다. layer를 쌓는 것은 조건에 따라 단순하게 쌓기만 하면 됐으나, loss 부분이 난이도가 있었다. 특히 noobj_loss가 왜 2개가 있는지 이해하지 못하였는데 이는, 셀에서 2개의 box를 predict하는데 2개의 box 모두에서 object를 contain 하지 않는 것의 loss가 noobj_loss1이고 2개의 box중 하나의 box만 object를 contain 하지 않는 것의 loss가 noobj_loss2이다.
#
# 실험을 하면서 여러가지 경우에 대해 실험해보기 위해서 여러개의 파일을 띄워놓았는데 이로 인해 CUDA out of memory 오류가 발생하였다. 파일을 띄워놓고 실행만 하지 않으면 괜찮은줄 알았는데 그렇지 않았다.

# %% [markdown]
# ### *References*
# [1] https://www.pyimagesearch.com/2018/05/14/a-gentle-guide-to-deep-learning-object-detection/
#
# [2] https://github.com/Cartucho/mAP
